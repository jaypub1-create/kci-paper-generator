# %% [markdown]
# <a href="https://colab.research.google.com/github/jaypub1-create/kci-paper-generator/blob/main/260412_%EC%9E%91%EC%84%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=3
x+5
# Out:
# 8
